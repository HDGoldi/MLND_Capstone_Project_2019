# %%
import tensorflow.keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import glob
# %matplotlib inline

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Image Data Generator w/ no augmentation
#Scaling for pixels
piece_train_datagen = ImageDataGenerator(
    rescale = 1./255)
piece_test_datagen = ImageDataGenerator(
    rescale = 1./255)
piece_valid_datagen = ImageDataGenerator(
    rescale = 1./255)


#Flow data from directory

piece_train_iter = piece_train_datagen.flow_from_directory(
    directory = '../data/color_data/train',
    target_size = (135,135),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    seed=42
)

piece_test_iter = piece_test_datagen.flow_from_directory(
    directory = '../data/color_data/test',
    target_size = (135,135),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    shuffle=False,
    seed=42
)

piece_valid_iter = piece_valid_datagen.flow_from_directory(
    directory = '../data/color_data/valid',
    target_size = (135,135),
    color_mode = 'grayscale',
    class_mode = 'categorical',
    seed=42
)
# Out:
# Found 1227 images belonging to 3 classes.
# Found 335 images belonging to 3 classes.
# Found 331 images belonging to 3 classes.

# %%
#Define NN architecture

from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras.models import Sequential

piece_model = Sequential()
piece_model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(135, 135, 1)))
piece_model.add(MaxPooling2D(pool_size=2))
piece_model.add(BatchNormalization())
piece_model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
piece_model.add(MaxPooling2D(pool_size=2))
piece_model.add(BatchNormalization())
piece_model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
piece_model.add(MaxPooling2D(pool_size=2))
piece_model.add(GlobalAveragePooling2D())
piece_model.add(Dense(3, activation='softmax'))


piece_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 135, 135, 16)      80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 67, 67, 16)        0
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 67, 67, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 67, 67, 32)        2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 33, 33, 32)        0
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 33, 33, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 33, 33, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 195
# =================================================================
# Total params: 10,803
# Trainable params: 10,707
# Non-trainable params: 96
# _________________________________________________________________

# %%
# compile the model
piece_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

STEP_SIZE_TRAIN = piece_train_iter.n/piece_train_iter.batch_size
STEP_SIZE_VALID = piece_valid_iter.n/piece_valid_iter.batch_size

# %%
from tensorflow.keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='baseline_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
piece_hist = piece_model.fit_generator(generator=piece_train_iter, 
                          steps_per_epoch=STEP_SIZE_TRAIN, 
                          validation_data=piece_valid_iter, 
                          validation_steps=STEP_SIZE_VALID,
                          epochs=100, 
                          callbacks=[checkpointer], 
                          verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.18820, saving model to baseline_model.weights.best.hdf5
# 39/38 - 8s - loss: 0.5580 - accuracy: 0.7710 - val_loss: 1.1882 - val_accuracy: 0.4411
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.3236 - accuracy: 0.8941 - val_loss: 1.2599 - val_accuracy: 0.1511
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.2748 - accuracy: 0.8989 - val_loss: 1.4006 - val_accuracy: 0.1511
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 1.18820
# 39/38 - 4s - loss: 0.2477 - accuracy: 0.9177 - val_loss: 1.4874 - val_accuracy: 0.1511
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 1.18820
# 39/38 - 4s - loss: 0.2415 - accuracy: 0.9234 - val_loss: 1.6234 - val_accuracy: 0.1511
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.1859 - accuracy: 0.9381 - val_loss: 2.0986 - val_accuracy: 0.1511
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.2099 - accuracy: 0.9405 - val_loss: 1.9765 - val_accuracy: 0.1511
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.1607 - accuracy: 0.9405 - val_loss: 1.9428 - val_accuracy: 0.1994
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.1388 - accuracy: 0.9560 - val_loss: 1.4662 - val_accuracy: 0.3112
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.1121 - accuracy: 0.9666 - val_loss: 1.5327 - val_accuracy: 0.3051
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 1.18820
# 39/38 - 5s - loss: 0.1091 - accuracy: 0.9707 - val_loss: 1.6531 - val_accuracy: 0.2991
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 1.18820 to 1.12668, saving model to baseline_model.weights.best.hdf5
# 39/38 - 5s - loss: 0.1089 - accuracy: 0.9731 - val_loss: 1.1267 - val_accuracy: 0.4804
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 1.12668 to 0.56090, saving model to baseline_model.weights.best.hdf5
# 39/38 - 5s - loss: 0.0924 - accuracy: 0.9788 - val_loss: 0.5609 - val_accuracy: 0.7764
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.56090
# 39/38 - 5s - loss: 0.0760 - accuracy: 0.9780 - val_loss: 0.5814 - val_accuracy: 0.7583
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.56090 to 0.33362, saving model to baseline_model.weights.best.hdf5
# 39/38 - 5s - loss: 0.0834 - accuracy: 0.9747 - val_loss: 0.3336 - val_accuracy: 0.8882
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.33362 to 0.18637, saving model to baseline_model.weights.best.hdf5
# 39/38 - 5s - loss: 0.0524 - accuracy: 0.9853 - val_loss: 0.1864 - val_accuracy: 0.9396
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.18637
# 39/38 - 5s - loss: 0.0748 - accuracy: 0.9804 - val_loss: 0.6680 - val_accuracy: 0.7976
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.18637
# 39/38 - 4s - loss: 0.0521 - accuracy: 0.9878 - val_loss: 0.2652 - val_accuracy: 0.8943
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.18637
# 39/38 - 5s - loss: 0.0508 - accuracy: 0.9853 - val_loss: 0.8505 - val_accuracy: 0.8912
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.18637
# 39/38 - 5s - loss: 0.0566 - accuracy: 0.9861 - val_loss: 0.8552 - val_accuracy: 0.7915
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.18637 to 0.14239, saving model to baseline_model.weights.best.hdf5
# 39/38 - 5s - loss: 0.0427 - accuracy: 0.9894 - val_loss: 0.1424 - val_accuracy: 0.9577
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.14239
# 39/38 - 5s - loss: 0.0479 - accuracy: 0.9910 - val_loss: 1.8217 - val_accuracy: 0.8429
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.14239
# 39/38 - 5s - loss: 0.0425 - accuracy: 0.9878 - val_loss: 0.7808 - val_accuracy: 0.8187
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.14239 to 0.13446, saving model to baseline_model.weights.best.hdf5
# 39/38 - 7s - loss: 0.0542 - accuracy: 0.9886 - val_loss: 0.1345 - val_accuracy: 0.9517
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.13446
# 39/38 - 7s - loss: 0.0231 - accuracy: 0.9951 - val_loss: 0.1394 - val_accuracy: 0.9668
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.13446 to 0.05480, saving model to baseline_model.weights.best.hdf5
# 39/38 - 7s - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.0548 - val_accuracy: 0.9940
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.05480
# 39/38 - 7s - loss: 0.0310 - accuracy: 0.9935 - val_loss: 0.1031 - val_accuracy: 0.9517
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.05480
# 39/38 - 7s - loss: 0.0231 - accuracy: 0.9951 - val_loss: 0.5950 - val_accuracy: 0.9033
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.05480
# 39/38 - 7s - loss: 0.0232 - accuracy: 0.9935 - val_loss: 0.9700 - val_accuracy: 0.8731
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.05480 to 0.03081, saving model to baseline_model.weights.best.hdf5
# 39/38 - 7s - loss: 0.0155 - accuracy: 0.9976 - val_loss: 0.0308 - val_accuracy: 0.9909
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0250 - accuracy: 0.9951 - val_loss: 0.4187 - val_accuracy: 0.8973
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0101 - accuracy: 0.9992 - val_loss: 1.0675 - val_accuracy: 0.9003
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.0396 - val_accuracy: 0.9940
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.03081
# 39/38 - 8s - loss: 0.0210 - accuracy: 0.9927 - val_loss: 0.0691 - val_accuracy: 0.9819
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0239 - accuracy: 0.9943 - val_loss: 0.0389 - val_accuracy: 0.9819
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0616 - val_accuracy: 0.9789
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0079 - accuracy: 0.9992 - val_loss: 0.1656 - val_accuracy: 0.9275
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0204 - accuracy: 0.9943 - val_loss: 1.4385 - val_accuracy: 0.8792
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0203 - accuracy: 0.9951 - val_loss: 0.4133 - val_accuracy: 0.8912
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.4390 - val_accuracy: 0.8852
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.03081
# 39/38 - 8s - loss: 0.0090 - accuracy: 0.9992 - val_loss: 0.0396 - val_accuracy: 0.9879
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.03081
# 39/38 - 7s - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.0900 - val_accuracy: 0.9547
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.03081 to 0.02820, saving model to baseline_model.weights.best.hdf5
# 39/38 - 8s - loss: 0.0138 - accuracy: 0.9943 - val_loss: 0.0282 - val_accuracy: 0.9909
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 3.0801 - val_accuracy: 0.7885
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0494 - val_accuracy: 0.9879
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.02820
# 39/38 - 8s - loss: 0.0167 - accuracy: 0.9959 - val_loss: 0.0496 - val_accuracy: 0.9879
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0702 - val_accuracy: 0.9909
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.02820
# 39/38 - 8s - loss: 0.0124 - accuracy: 0.9992 - val_loss: 0.0585 - val_accuracy: 0.9849
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.02820
# 39/38 - 8s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9970
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0287 - accuracy: 0.9951 - val_loss: 0.2778 - val_accuracy: 0.9275
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.02820
# 39/38 - 8s - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0408 - val_accuracy: 0.9849
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0136 - accuracy: 0.9959 - val_loss: 0.7939 - val_accuracy: 0.8792
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.02820
# 39/38 - 7s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.2361 - val_accuracy: 0.9245
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.02820 to 0.02181, saving model to baseline_model.weights.best.hdf5
# 39/38 - 8s - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0218 - val_accuracy: 0.9970
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0244 - accuracy: 0.9943 - val_loss: 0.0793 - val_accuracy: 0.9849
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.0520 - val_accuracy: 0.9909
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0543 - val_accuracy: 0.9909
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0817 - val_accuracy: 0.9758
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0024 - accuracy: 0.9984 - val_loss: 0.0371 - val_accuracy: 0.9909
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 9.0408e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9909
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0436 - accuracy: 0.9959 - val_loss: 0.0979 - val_accuracy: 0.9698
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.02181
# 39/38 - 7s - loss: 0.0077 - accuracy: 0.9959 - val_loss: 7.4263 - val_accuracy: 0.7130
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.02181 to 0.01761, saving model to baseline_model.weights.best.hdf5
# 39/38 - 7s - loss: 0.0190 - accuracy: 0.9951 - val_loss: 0.0176 - val_accuracy: 0.9970
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 9.7286e-04 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9970
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 6.0119e-04 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9879
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 7.7386e-04 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9819
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0202 - accuracy: 0.9967 - val_loss: 0.0415 - val_accuracy: 0.9940
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0027 - accuracy: 0.9992 - val_loss: 2.1867 - val_accuracy: 0.8792
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.7631 - val_accuracy: 0.9094
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.9441 - val_accuracy: 0.9124
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0351 - val_accuracy: 0.9940
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0151 - accuracy: 0.9967 - val_loss: 0.0867 - val_accuracy: 0.9879
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.8852
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0014 - accuracy: 0.9992 - val_loss: 2.4573 - val_accuracy: 0.8610
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0160 - accuracy: 0.9976 - val_loss: 0.0800 - val_accuracy: 0.9849
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 5.5025e-04 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 0.9909
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0056 - accuracy: 0.9976 - val_loss: 0.0762 - val_accuracy: 0.9819
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 3.2773e-04 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9909
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0057 - accuracy: 0.9976 - val_loss: 0.0333 - val_accuracy: 0.9940
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 1.7259e-04 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9940
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.2057 - val_accuracy: 0.9335
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 1.2612e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9909
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 1.6006e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9758
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0744 - accuracy: 0.9959 - val_loss: 0.0438 - val_accuracy: 0.9909
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 2.9736e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9940
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.0845 - val_accuracy: 0.9849
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 0.0038 - accuracy: 0.9992 - val_loss: 1.4980 - val_accuracy: 0.8731
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 0.0042 - accuracy: 0.9984 - val_loss: 2.4610 - val_accuracy: 0.9094
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0240 - accuracy: 0.9992 - val_loss: 0.0850 - val_accuracy: 0.9789
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 2.2151e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9970
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.5095 - val_accuracy: 0.8792
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 6.9189e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9970
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0062 - accuracy: 0.9976 - val_loss: 1.9329 - val_accuracy: 0.9094
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 3.5212e-04 - accuracy: 1.0000 - val_loss: 1.0511 - val_accuracy: 0.9124
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 4.1278e-04 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9970
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0274 - accuracy: 0.9967 - val_loss: 0.0364 - val_accuracy: 0.9940
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0018 - accuracy: 0.9984 - val_loss: 0.0383 - val_accuracy: 0.9940
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.01761
# 39/38 - 7s - loss: 0.0186 - accuracy: 0.9992 - val_loss: 0.0378 - val_accuracy: 0.9909
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 2.0057e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9909
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.01761
# 39/38 - 8s - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0286 - val_accuracy: 0.9909

# %%
#Reset test iterator
STEP_SIZE_TEST = piece_test_iter.n/piece_test_iter.batch_size
piece_test_iter.reset()
# load the weights that yielded the best validation accuracy
piece_model.load_weights('baseline_model.weights.best.hdf5')
# evaluate and print test accuracy
score = piece_model.evaluate_generator(generator=piece_test_iter,steps=STEP_SIZE_TEST)
print('\n', 'Test accuracy:', score[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-251f68dda02a> in <module>
#       3 piece_test_iter.reset()
#       4 # load the weights that yielded the best validation accuracy
# ----> 5 piece_model.load_weights('baseline_model.weights.best.hdf5')
#       6 # evaluate and print test accuracy
#       7 score = piece_model.evaluate_generator(generator=piece_test_iter,steps=STEP_SIZE_TEST)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/network.py in load_weights(self, filepath, by_name)
#    1495         hdf5_format.load_weights_from_hdf5_group_by_name(f, self.layers)
#    1496       else:
# -> 1497         hdf5_format.load_weights_from_hdf5_group(f, self.layers)
#    1498
#    1499   def _updated_config(self):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in load_weights_from_hdf5_group(f, layers)
#     759                        str(len(weight_values)) + ' elements.')
#     760     weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 761   K.batch_set_value(weight_value_tuples)
#     762
#     763
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/backend.py in batch_set_value(tuples)
#    2878   if ops.executing_eagerly_outside_functions():
#    2879     for x, value in tuples:
# -> 2880       x.assign(np.asarray(value, dtype=dtype(x)))
#    2881   else:
#    2882     with get_graph().as_default():
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#    1052     with _handle_graph(self.handle):
#    1053       value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
# -> 1054       self._shape.assert_is_compatible_with(value_tensor.shape)
#    1055       assign_op = gen_resource_variable_ops.assign_variable_op(
#    1056           self.handle, value_tensor, name=name)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1070     """
#    1071     if not self.is_compatible_with(other):
# -> 1072       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1073
#    1074   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (64, 3) and (64, 7) are incompatible

# %%
piece_test_iter.reset()
piece_pred = piece_model.predict_generator(piece_test_iter,steps=STEP_SIZE_TEST,verbose=1)

# %%
predicted_class_indices=np.argmax(piece_pred,axis=1)
print(predicted_class_indices)

# %%
labels = (piece_test_iter.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
truth =  [labels[k] for k in piece_test_iter.classes]

# %%
[labels[k] for k in piece_test_iter.classes]

# %%
piece_test_iter.filenames

# %%
filenames=piece_test_iter.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Truth": truth,
                      "Predictions":predictions})

# %%
results

# %%
from sklearn.metrics import classification_report
class_report = classification_report(piece_test_iter.classes,predicted_class_indices)
print(class_report)

# %%
from sklearn.metrics import confusion_matrix
cmatrix = confusion_matrix(piece_test_iter.classes,predicted_class_indices)
print(cmatrix)
print(labels)

# %%
from sklearn.metrics import log_loss
log_loss_result = log_loss(piece_test_iter.classes,piece_pred)
print(log_loss_result)

# %%
plt.plot(piece_hist.history['acc'])
plt.plot(piece_hist.history['val_acc'])
plt.title('Baseline Color Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
plt.plot(piece_hist.history['loss'])
plt.plot(piece_hist.history['val_loss'])
plt.title('Baseline Color Model Log Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
import seaborn as sns
ax = sns.heatmap(cmatrix, annot=True, xticklabels=['black','empty','white'],yticklabels=['black','empty','white'])
